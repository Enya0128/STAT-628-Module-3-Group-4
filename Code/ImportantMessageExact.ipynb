# %% [markdown]
# ## Init

# %%
import pandas as pd
import numpy as np
import os
import re
import nltk
from sklearn import feature_extraction
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('universal_tagset')

from google.colab import drive
drive.mount('/content/drive')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_review_original = pd.read_csv('/content/drive/My Drive/STAT628/data/mexican_review.csv')
df_review = pd.read_csv('/content/drive/My Drive/STAT628/data/mexican_review_p.csv')
df_business = pd.read_csv('/content/drive/My Drive/STAT628/data/mexican_info.csv')
df = pd.merge(df_review, df_business[['business_id', 'city']], on = 'business_id', how = 'left')
stars = df.stars.values.tolist()
target = []
for i in stars:
    if i in [1.0, 2.0]: # 
        target.append(1.0)
    elif i in [4.0, 5.0]:
        target.append(3.0)
    else:
        target.append(2.0)
df['target'] = target
df.head()
# Out:
#    index               review_id  ...       city target
# 0      0  6BnQwlxRn7ZuWdzninM9sQ  ...    Phoenix    2.0
# 1      1  S337tATeouQJdoPYyir29w  ...  Las Vegas    3.0
# 2      2  j3vP8537KHvoXNHQIr3haA  ...  Henderson    3.0
# 3      3  CvJy7CdHJqsZNq22fUF7hA  ...   Chandler    1.0
# 4      4  a6N51Ov3NEchmqsquNGtMA  ...      Tempe    3.0
#
# [5 rows x 12 columns]

# %% [markdown]
# ## Functions

# %%
def get_importance(df, city, vocab_size = 5000, max_train_sample = 50000):
    df_new = df[df['city']==city].copy()

    np.random.RandomState(0)
    if df_new.shape[0] > max_train_sample: # if review size if too larget, randomly choose 'max_train_sample' reviews
        rand = np.random.choice(df_new.shape[0], size = max_train_sample, replace = False)
        text = df_new.text.values[rand].tolist()
        y = df_new.target.values[rand].tolist()
    else:
        text = df_new.text.values.tolist()
        y = df_new.target.values.tolist()

    vectorizer = CountVectorizer(max_features = vocab_size)
    word_vector = vectorizer.fit_transform(text).toarray()
    word_list = vectorizer.get_feature_names()

    del vectorizer
    del text

    clf = RandomForestClassifier(random_state=0, n_estimators=20, max_depth=100)
    clf.fit(word_vector, y)
    del word_vector
    del y

    word_importance = clf.feature_importances_.tolist()
    importance_dict = dict(zip(word_list, word_importance))

    del clf
    del word_list
    del word_importance

    return df_new, importance_dict

def get_important_review(df, importance_dict, max_length = 30):
    # words to ignore in negative reviews
    block_words = ['good', 'great', 'like', 'fuck', 'recommend', 'pretty', 
                   'excite', 'excellent', 'nice', 'decent', 'happy', 'love',
                   'prefer', 'enjoy', 'order', 'food', 'amaze', 'delicious',
                   'return', 'go', 'back']
    
    # edit importance_dict to lower the influence of positive words in negative reviews
    for b in block_words: 
        try:
            importance_dict[b] = 0.
        except:
            pass
    
    scores = []
    df = df.loc[df['target']==1.0] # only consider negative reviews
    text = df.text.values.tolist()
    useful = df.useful.tolist()
    funny = df.funny.tolist()
    cool = df.cool.tolist()
    for i in range(len(text)):
        score = 0
        text_list = text[i].split(' ')
        i_list = []
        for j in text_list:
            try:
                i_list.append(importance_dict[j])
            except:
                pass
        i_list.sort(reverse = True)
        score = sum(i_list[:max_length])
        social_score = useful[i] + funny[i] + cool[i]
        score += np.log(social_score+1)*0.01 # consider 'useful', 'funny', 'cool' numbers
        scores.append(score)
    
    df_new = df.copy()
    df_new['scores'] = scores
    df_new = df_new.sort_values('scores', ascending = False)

    del useful
    del funny
    del cool

    return df_new

def text_processing(text):
    
    text = text.lower()
    text = re.sub(r'[^a-zA-z0-9]', ' ', text)
    text = word_tokenize(text)
    text = [w for w in text if w not in stopwords.words('english')]
    text = [WordNetLemmatizer().lemmatize(w, pos = 'v') for w in text]
    text = ' '.join(text)
    
    return text

def word_filter(word_list, text):
    go_back = 0 # ignore sentences like 'I will never go back.'
    for g in ['worst', 'never', 'go', 'back', 'return']:
        if g in word_list:
            go_back += 1
    if go_back >=2:
        return True
    return False

def extract_sentence(df_business, df_city_scores, df_review_original, city, importance_dict, n_review = 3, max_length = 10):
    # max_length means how much high score words to consider in each sentence
    # n_review means how many top reviews to consider when extract sentences
    df_city_business = df_business[df_business['city']==city].copy()
    df_city_business = df_city_business[['business_id', 'name']]
    business = df_city_business.business_id.tolist()
    important_sentence = []
    important_indexes = []

    for bus in business:
        df_temp = df_city_scores[df_city_scores['business_id']==bus].copy()
        indexes = list(df_temp['index'])[:n_review]
        important_indexes.append(str(indexes))
        if indexes == []: # no negative review
            important_sentence.append('Currently your restaurant does not have 1 or 2 star reviews. Keep great!')
        else:
            texts = df_review_original.loc[df_review_original['index'].isin(indexes)].text.tolist()
            sentence_list = []
            for text in texts:
                text_list = re.split('\.|\n|\r|\!|\?', text)
                processed_list =  []
                scores = []
                for sentence in text_list:
                    processed_list.append(text_processing(sentence))
                for processed in processed_list:
                    word_list = processed.split(' ')
                    if word_filter(word_list, text):
                        score = 0
                    else:
                        i_list = []
                        for word in word_list:
                            try:
                                i_list.append(importance_dict[word])
                            except:
                                pass
                        i_list.sort(reverse = True)
                        score = sum(i_list[:max_length])
                    scores.append(score)
                sentence = text_list[scores.index(max(scores))]
                sentence = sentence.replace('\n', ' ')
                sentence = sentence.replace('\r', ' ')
                sentence = sentence.lstrip()
                sentence = sentence.rstrip()
                sentence = sentence+'.'
                sentence_list.append(sentence)
            important_sentence.append('|'.join(sentence_list))
    
    df_city_business['important_sentence'] = important_sentence
    df_city_business['indexes'] = important_indexes

    return df_city_business

def generate_csv(df, city):
    df_city, importance_dict = get_importance(df, city)
    df_city_scores = get_important_review(df_city, importance_dict)
    df_city_business = extract_sentence(df_business, df_city_scores, df_review_original, city, importance_dict)

    df_city_business.to_csv('/content/drive/My Drive/STAT628/data/ImportantSentence/sentence_'+str(city)+'.csv', index = False)

    return

# %% [markdown]
# ## Extract by City

# %% [markdown]
# ### Tunning

# %%
def rf_tune(vocab_size=5000, depth=100):
    city = 'Phoenix'
    df_new = df[df['city']==city].copy()

    np.random.RandomState(0)
    rand = np.random.choice(df_new.shape[0], size = 50000, replace=False)
    text = df_new.text.values[rand].tolist()
    y = df_new.target.values[rand].tolist()

    vectorizer = CountVectorizer(max_features = vocab_size)
    word_vector = vectorizer.fit_transform(text[:len(text)]).toarray()
    word_list = vectorizer.get_feature_names()

    del vectorizer

    p = 40000
    clf = RandomForestClassifier(random_state=0, n_estimators=20, max_depth = depth)
    clf.fit(word_vector[:p], y[:p])

    print('vocab-'+str(vocab_size)+' depth-'+str(depth))
    print('Train Accuracy: %3f' % (np.sum(clf.predict(word_vector[:p]) == y[:p])/len(y[:p])))
    print('Test Accuracy: %3f' % (np.sum(clf.predict(word_vector[p:]) == y[p:])/len(y[p:])))
    print()
    
    return

# %%
vocab_size_list = [1000, 5000, 10000]
depth_list = [50, 75, 100, None]

for vocab_size in vocab_size_list:
    for depth in depth_list:
        rf_tune(vocab_size, depth)
# Out:
# vocab-1000 depth-50
# Train Accuracy: 0.955425
# Test Accuracy: 0.800800
#
# vocab-1000 depth-75
# Train Accuracy: 0.982900
# Test Accuracy: 0.801700
#
# vocab-1000 depth-100
# Train Accuracy: 0.992025
# Test Accuracy: 0.799800
#
# vocab-1000 depth-None
# Train Accuracy: 0.998550
# Test Accuracy: 0.804600
#
# vocab-5000 depth-50
# Train Accuracy: 0.926925
# Test Accuracy: 0.795400
#
# vocab-5000 depth-75
# Train Accuracy: 0.966500
# Test Accuracy: 0.802400
#
# vocab-5000 depth-100
# Train Accuracy: 0.985100
# Test Accuracy: 0.811300
#
# vocab-5000 depth-None
# Train Accuracy: 0.998050
# Test Accuracy: 0.805800
#
# vocab-10000 depth-50
# Train Accuracy: 0.911975
# Test Accuracy: 0.774300
#
# vocab-10000 depth-75
# Train Accuracy: 0.958550
# Test Accuracy: 0.789100
#
# vocab-10000 depth-100
# Train Accuracy: 0.978750
# Test Accuracy: 0.796600
#
# vocab-10000 depth-None
# Train Accuracy: 0.998700
# Test Accuracy: 0.800600

# %%
rf_tune(vocab_size = 20000, depth = 100)
# Out:
# vocab-20000 depth-100
# Train Accuracy: 0.972625
# Test Accuracy: 0.784500

# %%
city = 'Phoenix'

df_city, importance_dict = get_importance(df, city)
df_city_scores = get_important_review(df_city, importance_dict)

# %%
df_city_business = extract_sentence(df_business, df_city_scores, df_review_original, city, importance_dict)

# %%
df_city_business.head(10)
# Out:
#               business_id  ...                indexes
# 0  1Dfx3zM-rW4n-31KeC8sJg  ...  [20431, 27350, 25702]
# 1  Rs8Wi4OEjeOX7LVlzsXDOA  ...   [36718, 5288, 27403]
# 2  c7JoAt6a3Ufkpn3TrGU23A  ...         [38375, 39500]
# 3  UdL8Z06DaNj6qhen0fEH9A  ...   [11085, 7702, 27340]
# 4  3-aEgS7X2jrbxA7sA1nARw  ...  [27880, 17530, 13432]
# 5  rwscnQMpddjkVNaJQhNuHw  ...   [23024, 35599, 7633]
# 6  9vub2LM7Djy8P-LPumcLXA  ...   [38499, 3623, 21328]
# 7  giCq1MmW-_S2tvNOAHvJcQ  ...      [2980, 614, 8671]
# 8  v7UIeEvwNd3fleFE6icm3A  ...                     []
# 9  yb7ZtgMWSZboG_sSUx9g2A  ...  [18146, 25504, 23957]
#
# [10 rows x 4 columns]

# %%
sen = df_city_business.important_sentence.tolist()
indexes = df_city_business.indexes.tolist()

for i in range(100):
    print(df_city_business.business_id.values[i])
    print(df_city_business.indexes.tolist()[i])
    if sen[i] == 'Currently your restaurant does not have 1 or 2 star reviews. Keep great!':
        sen_list = [sen[i]]
    else:
        sen_list = sen_list = df_city_business.important_sentence.tolist()[i].split('|')
    index = indexes[i]
    for j in sen_list:
       print(j)
    print(index)
    print()
# Out:
# 1Dfx3zM-rW4n-31KeC8sJg
# [20431, 27350, 25702]
# After little miss attitude brought my card back, I drove away and noticed the nice gay boy only gave me 3 fire sauces but I don't blame him since attitude magee seemed to rattle him a bit, so I backed up and waved down a new boy at the window and asked very nicely if i could please get more fire sauce and the nice mexican boy gave me such a big handful of fire sauce that was so unnecessary and ridiculous and gave me the most unpleasant look ever.
# In addition, while I was waiting for the equally  burnt quesadillas, one of the employees (female with dirty blonde hair) came out to ask "Who was it.
# Then like 10 years ago it was like "Yo Quiro Taco Bell" with that little annoying fucking Chihuahua which was OK Taco Bell was kind of hip and tasted craptastic, remember according to the movie Demolition Man with Sly all restaurants will eventually turn into Taco Bells.
# [20431, 27350, 25702]
#
# Rs8Wi4OEjeOX7LVlzsXDOA
# [36718, 5288, 27403]
# You walk in no one greets you, you sit down literally 20 minutes passed before waitress came another  40 minutes to get served  there was only 3 people in restaurant rude customer service Will Not Be coming here again.
# I will actually say that service was bad when they open and it's gotten worse as time passes.
# I'm always down to try a new sushi spot, but definitely made a mistake saying yes to this place.
# [36718, 5288, 27403]
#
# c7JoAt6a3Ufkpn3TrGU23A
# [38375, 39500]
# I came out with a fish taco & chimichanga platter & went into the bathroom with a bad stomach virus.
# This place could offer better service.
# [38375, 39500]
#
# UdL8Z06DaNj6qhen0fEH9A
# [11085, 7702, 27340]
# If there is one thing I dislike is paying high prices for poor service.
# It came with a side of rice(I've tasted better) & a side salad (it didn't come with dressing & I wanted dressing, the server never showed up to ask if we needed anything after we were served.
# Some one else said it was too much hype for something so bland and I agree.
# [11085, 7702, 27340]
#
# 3-aEgS7X2jrbxA7sA1nARw
# [27880, 17530, 13432]
# " She didn't even apologize or anything then we asked for water and the water tasted horrible.
# off, by some guy name Gabriel, this place lacks almost of everything, first, service obviously with a manager/owner or else like Gabriel you can only expect employees just like him, no motivation, no passion no nothing, therefore bad service, the place is very small so it gets very crowded at some events,while some people complained about that, again this guy Gabriel received  it as an offense telling people "if you don't like it, then leave.
# 15 minutes later, I asked for chips and salsa and a new server.
# [27880, 17530, 13432]
#
# rwscnQMpddjkVNaJQhNuHw
# [23024, 35599, 7633]
# The food was cold and portions were small for the price.
# The costumer service is horrible, the waitress was rude and took forever to take our order considering it was slow and an hour and a half near closing time was already putting away the table sauces which made us feel extremely uncomfortable and rushed to eat once we received our food.
# "Employee was observed draining cooked shrimp liquid into the floor drain, dropping some shrimp on the ground, picking up the shrimp and placing it back into the basket with other cooked shrimp.
# [23024, 35599, 7633]
#
# 9vub2LM7Djy8P-LPumcLXA
# [38499, 3623, 21328]
# The food tastes "okay", not amazing, not bad, their meat it's definitely better quality than a Filiberto's/Julioberto's, but the big downfall is that their tacos are not filling.
# For example, my hubby likes extra onions on everything, try to ask for that & u get answers like 'umm I'm not sure' , 'ummm we don't do extra' , 'ummm i guess I could ask'.
# To be fair, as I mentioned before, I only got the chicken tacos and a plain quesadilla - but jeez, if you can't make those simple things taste great then I have doubts about the rest of the menu items.
# [38499, 3623, 21328]
#
# giCq1MmW-_S2tvNOAHvJcQ
# [2980, 614, 8671]
# It gave me time to look at the decor (nice) and count the many security cameras (6, that I could see).
# Ok to charge for the cold fries replaced, but twice.
# When we got into the restaurant, they did not have a table for us and we were told that we would have to wait 15 - 20 minutes to be seated.
# [2980, 614, 8671]
#
# v7UIeEvwNd3fleFE6icm3A
# []
# Currently your restaurant does not have 1 or 2 star reviews. Keep great!
# []
#
# yb7ZtgMWSZboG_sSUx9g2A
# [18146, 25504, 23957]
# The burrito was horrible though and the wipe of the nose pretty much made me not want to come back anytime soon.
# I have never written a poor review for a restaurant but I just had to because it was just so bad.
# So when we asked if there was salsa they said it was in the salsa bar.
# [18146, 25504, 23957]
#
# 7mMRxAxiPvhyLvbmhnGFsQ
# [37774, 4258, 41341]
# Too bad they don't read these reviews to address the customer service issue.
# Didn't give us our sodas and when we asked about how to open them he handed us the bottle opener almost threw it at my aunt.
# Every single time we've came here the guy who takes the order is very rude to us.
# [37774, 4258, 41341]
#
# 9-3de3NJte9Y2YsE3yl2EA
# [39423, 24603]
# Todo esta muy mal en este "restaurant " la comida, el servicio.
# Shitty service and you get the tip added into your bill knowing their service is shit.
# [39423, 24603]
#
# 036SeqOKaKx89Liw5RDKqA
# [18550, 38293, 2916]
# I had the beef rolled taco's with guacamole and a bean tostada, my husband tried one of the combo plates, comes with rice and beans he had the Adovada, also has a very large tortilla that comes with it.
# Total price was $23, so like another reviewer said, I felt like the prices were a bit more expensive than other places.
# In all my years of Yelping, I've not given a 1 Star to many places.
# [18550, 38293, 2916]
#
# Ktia9NJfvxVxTLVcEnw9zQ
# [14716, 26740, 6521]
# I asked if she could just make me one  beef.
# But if you claim this is "the best Mexican food anywhere" or "so so good" (right out of a commercial script) or "fantastic Mexican food", your credibility takes a nose dive.
# This location not so much however there is a far better Mexican place up the road that serves way better options and ummm real Mexican food and I don't care if it's cheap here either.
# [14716, 26740, 6521]
#
# 9EkpAzQGQuIguaV12Zxn-A
# []
# Currently your restaurant does not have 1 or 2 star reviews. Keep great!
# []
#
# 50NTSGbZ3pN5643_K1IReA
# [41473, 20553, 18440]
# There are SO many MUCH better places in the area that even "average" should have a tough time.
# As we were paying and complaining to the manager the waitress takes cash out of the drawer and hands it out to us and says  "just keep the tip if you didn't like my service" in a rude attitude way.
# Never once did he come to the table and ask how the food was, by the way, the hostess brought me my food, the bus person my drink, chips and salsa.
# [41473, 20553, 18440]
#
# ZLRI8ZjrzEm5fRW-ahGz_g
# [39803, 12524, 39821]
# Her manager came and said we charge you 50 cents if you use your card.
# Everytime I come here, I am told a price at the drive at the mic which is much more than the price on the menu.
# The chicken in these tacos tasted horrible.
# [39803, 12524, 39821]
#
# 02eESJZNF3qigrJ3GNRgIQ
# []
# Currently your restaurant does not have 1 or 2 star reviews. Keep great!
# []
#
# 5rZxENz57t-SDv1tIS8lOg
# [19328, 4140, 27568]
# If the front end looks that bad, I would hate to see the back.
# Although the food was OK, the restaurant was in terrible condition.
# The lobby, salsa bar and even drink station were very dirty and unkept.
# [19328, 4140, 27568]
#
# 46hnat0aLao-qYWZkN9aBg
# [21153, 35672, 15060]
# He brought me the menu; I found a garlic shrimp dish and ok sounds good for 13.
# When done we had to ask for the check 2 times and then it took 10 minutes to get it back.
# She walked up to the girl who took my order and said Hi do you think I could get my refill on my coke that I ordered and the girl eye rolled again and said "well you didn't order it from me".
# [21153, 35672, 15060]
#
# UqhVZYUeoBGroYpZB-9jlQ
# [1701, 845, 22886]
# When she was done she proceeded to tell me to go ahead and order and our rude waitress decides to stop us  right there and tell us very loudly  that "that was a lot of food" she proceeded to tell us "she'll give us what ever we want" but, "I'm just saying that's a lot of food" how embarrassing is it for your server to make you feel embarrassed about what you want to order.
# Got there 10 minutes early and we wait for 10 before anyone spoke to us.
# When she finally took our drink order she didn't ask about appetizers which okay is fine but when it took another ten minutes to bring our drinks she said she would be right back to take our order but she didn't come back for another 15 mins.
# [1701, 845, 22886]
#
# VoTi4yVhTVyFdmxUpoyUsg
# [34521, 4233, 18744]
# The food 4 stars, the fact that it is family own and run is a 5 stars, but service that I have received from the manager, David is a -3 stars.
# Honestly, I have had much better carne asada burritos from Ralphs Rolling Snack Bar & Filibertos, for much less money.
# I had a groupon or yelp on so I thought it would be great to get a couple entrees and be able to try some stuff since I planned on eating there pretty often, grabbing take out on the way home from work.
# [34521, 4233, 18744]
#
# IZUDXIq5SULhQ5RGLCdB7g
# [17194, 41430, 36694]
# I would not RECCOMEND this place even in the winter when you could warm up from the cold air because the food was good.
# Wasn't disgusting, but I couldn't go so far as to say it was even ok.
# In terms of tacos and tacos alone, I'd say they're just okay for a quick-bite, but not quite as great as I had expected given all of their positive Yelp reviews.
# [17194, 41430, 36694]
#
# u5U7iPk2D6SPprqlT7yTGQ
# [19422, 18450, 3994]
# My wife got the chicken burrito and it had nothing but chicken in it.
# But being insanely rude to customers at the drive up window, practically throwing our debit card back, and intentionally sticking green salsa in our bag with a side of heavy eye rolling after we requested the red (in response to you asking which type, twice).
# TL;DR: Average food at average prices, poor customer service, don't order something with extras or they'll mess it up (this wasn't the first time.
# [19422, 18450, 3994]
#
# 9WtEKbNGOU-wo2Gic1hUpA
# [23495, 18123, 10128]
# Just spent 20 minutes waiting when there was only two cars at the drive thru.
# As It was horrible quality, why would you want more of it.
# When I walked in I also was not acknowledged I take it as they thought I was looking at menu but really they should have asked or greeted me and I could have ordered quicker but she decided to take 2 drive through orders before coming to me.
# [23495, 18123, 10128]
#
# da_QOspls2XoU5AZ6QNcww
# [22380, 27450, 3390]
# Honestly I was not rude and and always try to be pleasant, but little miss attitude was obviously not happy being there.
# I can tell they use the corn tortillas you cook before you serve (like the ones at Costco) and I do like the way they cook their cheese on the griddle so it's crispy in the tacos, but overall there's an off taste to the food.
# Confused, I walked away and asked for the 4oz cups for the salsa sent to the s bar only to find less than a scoop in either and onions and other debris in salsa I returned and asked and said would you mind.
# [22380, 27450, 3390]
#
# 75i9St7QE12NX5JM-Zt90g
# [22737, 9030, 26586]
# I had to ask several times for my drink also.
# The drive thru guy took it in the back n came back to tell me his manager said it was fake n is confiscating it.
# My tacos had no meat all  lettuce and cheese, and still didn't even fill up half the taco.
# [22737, 9030, 26586]
#
# vUJhUVmRMn9T4gsmz-L_Yg
# [4275, 26426, 29484]
# They bring you free chips and salsa, both looked great when they brought them out but I actually added salt to the salsa because it was so bland.
# I asked what is wrong with tea, she said don't know, do you want water.
# Don't expect to get seated if there are two empty tables and you come with a group of 5 or more.
# [4275, 26426, 29484]
#
# oVdcOfPFUHae6vRnAEzFFg
# []
# Currently your restaurant does not have 1 or 2 star reviews. Keep great!
# []
#
# PQWE8a6Opjiuzt7DaX2R6Q
# [16186, 28774, 28425]
# when the service is so poor that the conversation can go on & on without interruption for ANYONE asking if we needed water, salsa, does anyone want to take our order, would we like the check.
# Then before we had a chance to finish the game we were still in, he states we have two minutes to finish, and when we asked why he said he can do whatever he wants "because he works there.
# I know all the tricks of the trade and one is never assume, always ask; have you ordered your drinks, are you waiting for someone, can I get you anything.
# [16186, 28774, 28425]
#
# IYedXxcwJJwxv-6DpMPvtA
# [8489, 11534]
# I raised my hand so she could see and her and the cook started talking shit as if we can't hear them saying that " I don't understand why they get so mad when they're just going to tip a dollar".
# It's possible it has nothing to do with the food but the timing of it and the slightly off taste makes me think it was the food.
# [8489, 11534]
#
# _6mvQX9x66oz046eS5ii8w
# [39584, 4988, 23278]
# Then I asked to speak to a manager who could do something.
# I finally asked how much longer and was told there was a large table that was causing the wait.
# Be prepared to wait and no matter what, the wait to get your food is always slow no matter how empty or packed--ESPECIALLY if you order take out and ask how long before pick up will be ready.
# [39584, 4988, 23278]
#
# URwrgfuyfpVqgnKwkawlHw
# [12349, 27472, 20655]
# The guy taking orders was not very friendly at all.
# I don't know if it was a clean or dirty napkin, but that's disgusting.
# I was very irritated and I walked out so I could take a deep breath and go somewhere else.
# [12349, 27472, 20655]
#
# OFacUbdk0t-GJ83GQ83LOw
# [10831, 14767, 33585]
# As I was going through the line I was asking for recommendations on what she thought went best together but again, she seemed bother to help me and had a bad attitude.
# After she heats up the tortilla she asks me if I want chicken or pork.
# First off, I decided to try the fajita, since it's what I get from (angels sing) Chipotle, so it would make the best comparison.
# [10831, 14767, 33585]
#
# ibOX3CypYVz0nJhCN5Wmcw
# [42167, 1184, 18816]
# We finally got a waitress to take our drink order and she kind of seemed upset, because we had no lids on our drinks and I didn't even get a straw.
# After telling them they messed up my order and walked her through it again she said it would take 25 mi Minutes and the place was empty.
# The claim they have the best tacos in Arizona  they have the worst tacos and service in Arizona.
# [42167, 1184, 18816]
#
# 9cflYye_S2xNeb3C0mG3ng
# [30883, 6977, 10400]
# I left a dollar for the chips and salsa i ate while waiting for my waitress to return and walked out.
# This place is way overpriced and I think the 5 star reviews must be from wait staff and family members.
# We asked for drinks along with glasses of water and when the bill was given to us we discovered we were charged $3 for the water.
# [30883, 6977, 10400]
#
# pJdPcHkqtaLF47pS0LxdYQ
# [20037, 29925, 4132]
# Not much better as overall it was bland and the chicken pieces were fatty and had some gristle, but it was 1/2 the price and at this point I just wanted to get out of there.
# Finally our server greeted us with her presence, she walked up and didn't say "Hi, I'm so-and-so, I'll be taking care of you folks today" or "Welcome to Lenero, have you been here before" or even just "hello" instead she said "what can I get you to drink".
# Now, how anyone can say this is the best Mexican food they've ever had, must have left their taste buds at home, but I guess to each their own, right.
# [20037, 29925, 4132]
#
# XRtelzecxvhGtG4h7Xdxsw
# [9620, 33475, 5730]
# I was getting some meat at this store n my 6 year old points out a little bug.
# I never got a good attitude, from him, or frankly friendly service no matter how nice I am.
# Let me begin with the fact that I got there 10 minutes prior them closing and they were rushing me to finish shopping, I didn't really appreciated that.
# [9620, 33475, 5730]
#
# Ls1NqcogI-szYoQ7tLh4Og
# [36787, 4412, 35045]
# We left after one drink because it was so awful and went down the street to the Strand for much much better and friendlier service.
# It was okay, I think that it could have been at least served on a normal roll instead of a hotdog bun type roll because it seems a bit much to be asking for 10$ for such a small sandwich.
# Went up to the manager (or whoever is in charge there that night), and informed him that we had waited 10 minutes and got no service at ALL.
# [36787, 4412, 35045]
#
# ibf4xvHWD4t1DOOZhidHBg
# [15484, 8078, 9292]
# OK OK maybe I'm being a little harsh, and maybe this fellow hasn't seen any action in a while so I'll cut him a break, but just one.
# Our skinny margaritas this time were LOADED with ice (see photo) & when my friend asked for less ice on our second round, Rick said that that's the way they do it and they should never do it differently.
# When my husband finally asked, she said oh the kitchen is making the chips.
# [15484, 8078, 9292]
#
# CeuTRtwsq6w5rztGOyNMPg
# [2631, 31583, 22112]
# Again I say, the night crew is MUCH BETTER at how they treat the customers.
# Food flavor ok, but serving sizes are very poor.
# The carne asada was okay (a bit on the greasy side) but the beans in the burrito were beyond salty along with the rice.
# [2631, 31583, 22112]
#
# mss-LiOfL1vtoNo3WoEoJw
# [11540, 28763]
# Sign says open from 1030-8pm on Friday's though apparently decided to close when I paid for a visit.
# Basically just chicken taco-tostado overpriced for street taco size.
# [11540, 28763]
#
# yAXWKWRTs4wNy-zrJgoeXQ
# [37044, 39526, 735]
# I try not to write negative reviews but we left the restaurant upset and feeling was we just wasted our time and money.
# The tacos are just ok- chewy bland meat, dry chicken, overly salted everything.
# We experienced poor flavor profiles, uninspired copy-cat dishes, bad decisions for techniques & ingredients and found the food as lacking as the service.
# [37044, 39526, 735]
#
# feXaud0exONNXlUu1m9DZg
# [5735, 10281, 21283]
# It's cafeteria errrr um Subway style mexican food they ask you what you want and add it to your burro or w/e you get a tray and sit.
# If ever a reason to go there I guess the chips and salsa are ok.
# The food was the worst Mexican food I've ever had, I ordered the barbacoa tacos and the meat was cold it wasn't even warm.
# [5735, 10281, 21283]
#
# n4HJ0fTMwMEGx07tzhN7Gw
# []
# Currently your restaurant does not have 1 or 2 star reviews. Keep great!
# []
#
# 3X-jhrbCSMv5hfUS02xdHA
# [41695, 5671, 12901]
# Around this time is when I really started to simmer, because just a few  minutes earlier, two gentlemen had come in,  immediately got their order taken, received chips and had margaritas.
# Service was ok, not great, not horrible.
# He told us "yeah we get complaints all the time," and "there are people here, you can ask them for the checks" and "I've been working as a server for 25 years," The service was poor and you're making this place look bad by not giving good customer service.
# [41695, 5671, 12901]
#
# H-3l48X4ANDJeok4OxS2Vw
# [25587, 19710]
# Should have known better than to eat in a place so dark that you can't see the food on your plate.
# Horrible, it was old meat, plate was cold, sauce was split.
# [25587, 19710]
#
# SxqNnm4piAlFNNiBaXM0kg
# [38066, 25473, 3420]
# There are no vegetarian options (UGH) besides the B and C burrito but I asked the guy working if he could throw together a veggie taco with ingredients they had (potatoes chiles onion avocado).
# It was really too bad that the burrito was HUGE and we were excited because we were hungry and we knew that we had made a good decision to share because it was horrible.
# This was the worst experience I have had a restaurant in a long time.
# [38066, 25473, 3420]
#
# zdW81Pk8Q3jA5sMj9AHOrA
# [7782, 9628, 3213]
# Tortillas were hard & cold & the meat looked more like lengua & it was just bad all the way around & my Jamaica drink tasted AWFUL with a bad after taste-chalky-Ewww.
# This location by far has the worst customer service.
# I called to informed them and was told that in order for them to exchange I would need to take it back for them to add the other ingredients (not enough time left at lunch to do this) and was told too bad nothing they can do.
# [7782, 9628, 3213]
#
# G-uuABMCbX0MYf0gQDVfKg
# [36751, 6026, 20397]
# We asked about the house margarita and how it was and she told us that it was pre-mixed and that honestly she it wasn't that good but it was "award winning" truly, the only award this margarita could have possibly won is the worst margarita in town award.
# They got our order wrong for our margaritas and then never brought us chips and salsa even though we asked three times.
# instead we have to ask for each thing individually because i feel like a jerk asking for 5 things that most places bring automatically.
# [36751, 6026, 20397]
#
# p4YvOzp42g3JzlXJny8F0g
# [28116, 39942, 6018]
# After being sat in a sauna for what was like 20 minutes, and being asked by every server if someone took our drink order, we are finally get drinks.
# with that said, I am always enthusiastic about an authentic family-owned Mex restaurant, but Pepe's was just mediocre.
# When I went to pay and asked for my waitress name so I could include her in my review the lady refuse to give it to me.
# [28116, 39942, 6018]
#
# NhGkSF9UB3hiDKUY9roHBg
# [132, 2173, 22327]
# When I got to the window the I said I asked you to turn on the light so I could see the menu.
# If I could give less than 1 star,  I'd give them zero.
# The breakfast burrito was like a home burrito and the quesadilla was 1 flour tortilla, a little bit of cheese and meat.
# [132, 2173, 22327]
#
# cHdJXLlKNWixBXpDwEGb_A
# [20995, 2633, 20521]
# I ordered a jade red burrito, they gave me something with slimy pork inside, and I asked for a veggie quesadilla, they gave me a quesadilla with gross fatty chicken and a horrible sauce.
# I feel really bad about giving this place a bad review, especially since they were so nice about giving free samples before I ordered.
# He was so rude, I at this point refused to give my money to such a disrespectful person, so I left and sadly ended up going to jack and a box.
# [20995, 2633, 20521]
#
# fbQaKW0Lte0JQ_opbnjdKg
# [2670, 16316, 31732]
# I asked for a sample of the chicken because I've never been and was having a hard time ordering, the guy looked at me like I was stupid for asking.
# Well probably be back to try them one more time as I really want these guys to succeed because I live right down the street and I love their concept, but if I get another room temperature bowl of soup it'll definitely be a MAJOR issue.
# I guess I was really expecting more, considering all the positive reviews I read and this is why I feel terrible for saying the food at  Gadzooks was bland and poorly executed.
# [2670, 16316, 31732]
#
# ypFzLKsbvM-HjTfMQKQkSQ
# [9547, 38175, 25489]
# Both came with 3 tacos, rice and beans, and at $8 a plate, I wouldn't really call this a good deal, especially since chips and salsa were an additional $1.
# caught the employees dumpster diving behind the building for plastic bottles to take and get $ to recycle.
# It reminded me of nothing more than what I would get at a Fillibertos.
# [9547, 38175, 25489]
#
# vGDhK2Lc4Np5iZYZ7FG0QA
# [15508, 12570, 25025]
# My other co-worker got the carne asada and he felt it was very bland.
# It was the WORST service I have ever had.
# She couldn't give a run down about the chocolate tamales it was just too stressful for her to do so, instead I got rude gestures and remarks.
# [15508, 12570, 25025]
#
# AIMfPkVKeBqnCysGMv5XRw
# [33760]
# Well I cannot comment the the food (looks delicious by the way) I just could never get get in touch with anyone to inquire about their business, customer service that's kind of important to me.
# [33760]
#
# mcXRNuN1MsgXYt8B2MWz2Q
# [1280, 23444, 14995]
# I don't usually give places bad reviews but when Ive given this place numerous chances and everytime it disappoints than it needs to be addressed to others.
# So I wasted even more of my time by typing up and faxing a letter to the general manager, but I never received any response and of course no refund to my credit card, and would rather eat sand than eat at this Filiberto's again.
# Filibertos has always been bad but this location is the worst of all.
# [1280, 23444, 14995]
#
# nsEO3MRzYLKfgtID7gvArw
# [11621, 37378, 35997]
# Also if you check out my pic I added if the waitresses have the time to play games on their phones and screw off they can defiantly provide better service or even clean this filthy place.
# " This is a awkward question to ask someone about to use your restroom but its still better than NO YOUR NOT USING THAT RESTROOM ITS FOR PAYING CUSTOMERS ONLY.
# When the bill came, we didn't even complain or ask that the price of the rice be removed from the bill BECAUSE:.
# [11621, 37378, 35997]
#
# mIZRTk10-YmWRVaxhC1hjg
# [23754, 34759, 36029]
# My unadventerous teen said his beef burrito was one of the worst meals he's had in a while.
# It's hard to give a two-star review for Karey's Kitchen given the storm of very positive reviews so far, but anything more feels really inaccurate given my two experiences there.
# I'm surprised people rated the food here 4 stars(30 reviews at this time), clearly the customer service is warm and friendly, but the food is not good.
# [23754, 34759, 36029]
#
# 5WtKBzHv1mL2-w1wcz3kpw
# [49034, 59478, 64234]
# The lady then said she was wrong about it coming with cheese but said she'd ask the owner if they could remake it for me because of what happened.
# Time for other people too, to find another place to buy mexican food, some where they appreciate your business instead of taking it for granted.
# I asked for my money back so the girl swiped my card and said it's back on your card.
# [49034, 59478, 64234]
#
# VuYF1vGKLjEFaQfL4Ypwqg
# [46812, 78889, 56172]
# It took her another 10 minutes after we spoke to her to come back and take the order, and we had to ask three times for water.
# I asked the server about it and she walked away rudely saying she'll get it taken off the bill without trying to correct anything.
# I calmly informed her that we had to leave she became indignant and asked us to wait once again while she brought the manager to speak to us, even before we could leave our seats she ran off to the back of the restaurant and waited for us to exit the place.
# [46812, 78889, 56172]
#
# nVGPxMooxSiaSH_wHvcRbw
# [69452, 50278, 77958]
# So we sat down, and about two minutes later the kid comes out and says that now they do have nacho cheese.
# Pay for my order and the cashier says "just waiting on your 2 double decker tacos" which I reply "I didn't order and tacos".
# I thought that was very rude especially when I know there is such an item and that I always order the same thing and have for years.
# [69452, 50278, 77958]
#
# n6AxJR-ey2_DgAJPZfEvfQ
# [59686, 44513, 64456]
# After 20 minutes of waiting and watching three groups after us get their orders, I went up to ask about my food.
# I told her the two burritos, she checked with someone in the back and said that they could make them but it would be a little bit.
# Third, the customer service is totally non-existent you would think after waiting so long you would get some sort of apology or gee thanks for waiting but nothing at all not even during the transaction or after.
# [59686, 44513, 64456]
#
# -zhywnaBiGRNcr6kbDagBQ
# [80759, 72928]
# I would have taken it back and asked for them to remake it but it took so long to get our food that I would be late for church if I waited.
# Ordered a California burrito definitely one of the worst I've had.
# [80759, 72928]
#
# rmD9BPsucgR4q3WiygrjEA
# [47513, 63100, 60193]
# The food was ok nothing I would brag about or go out if my way to go there.
# I have 2 reviews first one had nothing but great things to say about ozzys.
# Even though this is a roach coach, I would expect a lil more if they want to be "restaurant" style with waitresses, sit and we will take your order.
# [47513, 63100, 60193]
#
# M9aTtOeOIG-EOLeHNgkKfQ
# [78377]
# I ate a breakfast burrito today, my husband and I eat tacos here all the time.
# [78377]
#
# IghwtXL8ZgK2dEL62Pzhrw
# [73419, 79765, 79650]
# We arrive home and sit down for our meal to our disappointment they had forgotten 2 Carne asada tacos, the tripas were once again excessively chewy (not fried at all), and the menudo was cold, greasy and lacking flavors that it's well known for.
# Staff was overall pretty rude & the tacos were.
# The food was okay, Their pastor tacos has too much fat, the longaniza tacos are not good and their tripas taco did not have lots of meat.
# [73419, 79765, 79650]
#
# MVLZqbw6vOkCjFApRBlSfQ
# [50371, 54707, 43428]
# Will never give them my business, as there are too many small mom and pop Mexican food operations that have great food and treat you very well.
# Taco Bell does a better jobat this lunch time favorite than these guys do.
# 08 for rolled tacos and a drink  took one taste and left maybe thats why they have a sign   NO REFUNDS when your not satisfied anywhere else with your meal  cant you get your money back.
# [50371, 54707, 43428]
#
# 2tC8oReqFUT0_uVQ3kHePA
# [69884, 52973, 69282]
# I seriously thought they would say "hang on sec, we have some fresh steak coming".
# Told her two times we had never been in before and asked her how it worked and she could barely even respond -very short and unhelpful.
# Too much of a hassle on the refund after the card was already charged, so let it go, but bad training, service and a bad burrito made this an unbearable eating experience.
# [69884, 52973, 69282]
#
# sKHDoLqDj99UuAP8ljSaTw
# [57127, 45503, 57637]
# We asked how come they take online orders and the employee said she didn't know.
# As we approached the register we asked another employee (possibly the manager), why the portions seemed to be half of what we are normally used to getting at Qdoba.
# 00 for mine & then a dirty guy on a scooter comes in, after eating food out of the outside trash in front of us, and gets a burrito bowl & a soda for free.
# [57127, 45503, 57637]
#
# YM-nYIHd99qUt9n62AxIAg
# [69248, 63373, 57173]
# I asked for the manager and told them to keep the cold pollo fundido.
# 95 due to not having the item on the menu ok fair enough the pizza was cold the cheese was stiff very stiff the pizza was also not even cut with a pizza cutter completely in tact, the chimi was however ok just shredded chicken wrapped in a tortilla,.
# Anyways NEVER did the waitress came by to ask if we needed anything and when we finally tracked her down to get a sauce of some sort to sauce to put on the fajitas to make them eatable, rather than ask if we would like something else she brought us enchilada sauce with an attitude.
# [69248, 63373, 57173]
#
# dHmLezNmX-VW8_Hfryv5tA
# [44950, 65785]
# Now the food: I ordered green chili pork, which was good, until I got tho the center part of the meat, which was cold, not even warm, cold, a good 40°F.
# Horrible experience, I probably won't be coming back.
# [44950, 65785]
#
# bo05yEhBVDA6YFOST_Gqlg
# [79767, 81010, 79894]
# Even if our entrees were hot; it would not have made a difference the food was bland and tasteless.
# I ordered tacos to go and the sauce they give you is too spicy for my wife, so I asked if I could get a small amount of the salsa they use for the chips which is really mild so that my wife could put on her tacos.
# And when she brings it out she says the two burritos are different and I said they should be the same and she then starts saying you never said that and just stood there.
# [79767, 81010, 79894]
#
# jom1Jo6Uufn64Rz6payYSg
# [67112, 58800, 58446]
# Just wanted me some taco bell after 18 hours of not eating.
# The person who took my order was very nice, but I specifically asked (twice) for a VEGGIE power menu burrito and even stated that I am vegetarian.
# First time my fiancé and I came it wasn't horrible so we thought we would give them another chance.
# [67112, 58800, 58446]
#
# wAXYLmHuysYTz8i4VPKmaQ
# [49380, 78749, 50726]
# Usually a line for Chipotle but always moves fast I ordered 2 burritos, chicken for my girl and steak for me so as he was making my burrito I asked for half barbocoa and half steak he asked if I wanted double meat or just half and half and I said half and half.
# If I was a manager on duty, I definitely would have said something to him.
# When I did the cashier with blonde hair and tattoo with a heart on her arm told me I must have ordered to the wrong place so I showed her the location which said 425 E Bell Rd st 140, she replied saying "I'm not sure what the exact location of this chipotle is" then asked her coworker who did not know either.
# [49380, 78749, 50726]
#
# bVqNtwcwIz2gAacHWYF2lw
# [53588, 66047, 75836]
# Husband asked why it said that we could "pick 4" if she's now saying that it has to comes with those 4 specific things.
# Rachel was very apologetic about the printer and said she was going to go ask the owner what he could do for us.
# The worst part of the 2nd visit was the heat inside the place.
# [53588, 66047, 75836]
#
# Lqp3uwGJU6CHyys-eerMmQ
# [55819, 66944, 79724]
# Maybe the corn tortillas they use on their tacos deserve the accolades that other reviewers can't seem to stop talk about, but my flour tortilla was below average.
# With that being said I was for sure thought that the food would be top notch, Boy was wrong the I picked up my Taco and it all came out the bottom, the Tostada had a whole head of brown lettuce and a pinch of cheese, the Tamale WOW was the worse the Masa was thick and Dry that the plastic fork they give to eat with bent.
# With 4 stars on yep I was hoping for a tasty breakfast but after a long wait I got a plate of overcooked eggs, weird tasting greasy bacon, completely undercooked potatoes (how hard is it to cook taters until they are brown.
# [55819, 66944, 79724]
#
# VJVEDDJKccmrW1fhJCWmsQ
# [76161, 56997, 56916]
# Have tried to make sense of all the 5 star  reviews but I guess for phoenix this is better than nothing.
# I asked for them extra fried but to my surprised they were barely fried.
# The prices were decent & the size of the tacos were also decent so better than a one star rating for me.
# [76161, 56997, 56916]
#
# u4in1KQSQthNHcpDMjC1bw
# [76262]
# I walk in and saw a lot of lil bugs running around the floor sorry but i turned around and walk back out.
# [76262]
#
# k8gsrz7gunXPYlOvDfJNBg
# [57875, 57236]
# One thing that encouraged me to try this place was the big sign on the outside that says "Licuados" which is something I don't see on too many menus and which I absolutely love (it's kind of like a milk shake but I think the primary ingredients are milk and ice, not ice cream).
# Now, we waited in like at the drive through for fifteen minutes for two cars in front of us and once we got to the window it took about three minutes for them to even say hi and take our order.
# [57875, 57236]
#
# ju1jDr9nF0YCeTNKMYXPVA
# [61378]
# I hate to give bad reviews but this place just ain't recommended.
# [61378]
#
# viB8KE-lqVzuaeyh6M4Xhw
# [80943, 80609, 69215]
# The meat was dry and not seasoned, the beans and rice were bland and I might as well have been chewing styrofoam instead of their corn tortillas.
# Seems like burritos are an OK choice.
# Today I had carne Asada fries I thought to myself, surely they cannot mess this up but it was a disaster I got my fries and drove 10 minutes to my home and when I opened my box the fries were stale, mushy and The toppings were pushed to one side of the box.
# [80943, 80609, 69215]
#
# z6ttWFTaktvILeMYGNZPtw
# [51389, 60309]
# I asked the server if that was right.
# This Chuys moved and is now just east of 7th St on Greenway Parkway.
# [51389, 60309]
#
# bxLmrsMdjAyz8QEqWml1CA
# [79587, 62369]
# The mini chimichangas were probably the best part of the meal though one of them had unrolled a bit in the frying process.
# Chips (flour) and "salsa" were a little different and tasted fine, but i much prefer fresh salsa made with vegetables.
# [79587, 62369]
#
# MhwAKgF54Rwmm4vkdIb0Lw
# [48325, 69371, 71760]
# As I was getting water and waiting for my food I heard the shift leader tell the cashier she better have everything closed up in an hour.
# The food still came out wrong and the employee said my sister had never asked for the toppings on the side and threatened to charge her to change it.
# There's quite a few quick eat places at Desert Ridge to try out and even though I didn't get sick, there was something not right about those fish tacos.
# [48325, 69371, 71760]
#
# -2isRNVb6PDuBagELL5EBw
# [70891, 63161, 47157]
# Again, normally, especially a manager, the person would say you know what don't worry about it I'll get that made the way you want no extra charge.
# We continue to visit this location because we usually have a very nice lady by the name of Carol take our order and she gives us outstanding customer service.
# And I will assure I tell every person I know about your horrible service and bad employees.
# [70891, 63161, 47157]
#
# IVZ28eprMi_hoU2AXNuMTQ
# []
# Currently your restaurant does not have 1 or 2 star reviews. Keep great!
# []
#
# jsuUmIEefPjV__ads62Z5w
# [62970, 44242, 45586]
# Dickey's BBQ is just a pit and Dickie's Dog's apparently fed the wrong person a crappy hot dog one too many times and got fire bombs thrown through their front window for their trouble.
# The Eggs Benedit which I love were hard, the sauce dry and the pork, my favorite all dry too as if it had sat for awile keeping warm.
# He disappeared after giving me the beer and ten minutes later came back and asked if we knew what we wanted or had questions.
# [62970, 44242, 45586]
#
# KBP7x08WfD__BUoE4kY0lg
# [75710, 71214, 69273]
# borderline rude service and the place was not overly busy or crowded.
# OK, the girl asks me if I want regular or XL for my carne asade burrito (which they claim to be the best carne asada in town) I of course say XL because i like food and want a lot of it.
# Maybe it was just Cinco de Mayo, but I got here just before the lunch rush really got going to order a simple carne asada burrito (regular size) and I waited 45.
# [75710, 71214, 69273]
#
# A2eA3LRbptrexCGw8fu67Q
# [77585, 68662, 53307]
# The guy working said he would just get me more bacon.
# I don't like to give bad comments as it does hurt business, but it also helps the owners of the "ULSG" to correct cooking errors.
# Next time you don't want a customer to be "bitchy," try taking their order and giving it to the kitchen.
# [77585, 68662, 53307]
#
# 1JF9TbJ2d5hH8xsQvvklHg
# [77281, 54242, 77217]
# Rice was also bland.
# The red burro was ok.
# not sure where these 5 stars are coming from but this place had cold, bland, nasty food but worse was the customer service.
# [77281, 54242, 77217]
#
# xyrQByVfX47bstcmP_k1BA
# [78871, 55991, 69577]
# Service was horrible.
# Food was good but service TERRIBLE.
# Overall the combination of bland food, above average pricing, and passable decor means I would not recommend.
# [78871, 55991, 69577]
#
# xsdRrNJuNumvrwoQ2Tt8tQ
# [66200, 74996, 63362]
# The customer in line ahead of me mentioned that he had a bad attitude after I asked for fresh corn and cheese.
# I really hate the cold, bland food served here and am just scratching my head how anyone--other than those who have never had great Mexican--could even like it.
# While checking me out she kept on talking to her friend who was visiting her and did not work at the store and because she was distracted, she kept on asking me to repeat everything I was getting over and over again.
# [66200, 74996, 63362]
#
# QnCsCbE7EQte_MDWLO1gYg
# [76546, 64279, 72796]
# Now another employee called me back, I didn't leave my #, to ask if I'd like to come in for a free burrito.
# On another visit, my burrito was in better shape, but this time my steak wasn't quite right.
# When I asked for a new bowl shr huffed and puffed and threw the stuff together then when I corrected her the 5th time about my order having guacamole on the side she made the girl ring me up for the extra guacamole that I "never paid for.
# [76546, 64279, 72796]
#
# pNSHrFBlwWgTY9es9sdEWA
# []
# Currently your restaurant does not have 1 or 2 star reviews. Keep great!
# []
#
# b9kQOV8VK_ecGYVoIQiHrg
# [72192]
# They finally get us seated and we waited 15 minutes before the waiter came over to tell us ALL of his problems.
# [72192]
#
# RSEWEofaXj5W29C-WuFq4Q
# [75418, 75515]
# Well, I understand people come in late, have a bad day, so I was willing and happy with changing my order to bacon, but it STILL got messed up.
# On the positive side their medium salsa was quite good, but they just give you a squirt bottle when you get your food (i.
# [75418, 75515]
#
# lrAUseySfmFeZkWOGfsKnQ
# [54240, 53718, 61055]
# I am ALWAYS down with tacos for lunch, so I Yelp searched a few spots near work and decided to try this place out.
# So many other places that actually make AUTHENTIC street tacos that are hot, fresh, use fresh street taco style tortillas, and always come topped with fresh pico.
# Usually we see them grilling our taco meat fresh, this time we seen them scoop it out of a metal container and spoon it onto semi cold corn tortillas.
# [54240, 53718, 61055]
#
# Ntu_fC4eFSPsNbssHKEg2Q
# []
# Currently your restaurant does not have 1 or 2 star reviews. Keep great!
# []

# %%
i = 78871
df_review_original[df_review_original['index']==i].text.tolist()[0]
# Out:
# 'Went on a Wednesday night around 6:45.\n\nDecor is typical strip mall Mexican restaurant- Dos Equis signs and mariachi music. Service pace was good but the waitress spoke very little English. There were at least a dozen bottles of hot sauce on the table.\n\nThe waitress brought over chips and salsa plus bowls of a vegetable soup with seafood broth. Salsa was fresh and the soup was straightforward but interesting with the seafood broth.\n\nWe ordered fried calamari, which was a bit over cooked and bland even with the included sauce.\n\nMy companion got marlin tacos and enjoyed them. I got a mixed seafood cocktail which came with tostadas and crackers. The cocktail was very bland, with minimal seasoning or flavor.\n\nPricing was a couple bucks per item more than expected but not out of line for a seafood restaurant.\n\nGood Mexican food should always be fresh and flavorful. Overall the combination of bland food, above average pricing, and passable decor means I would not recommend.'

# %% [markdown]
# ### Csv Generating

# %%
cities = ['Las Vegas', 'Phoenix', 'Scottsdale', 'Toronto', 'Charlotte', 'Mesa', 'Henderson', 'Tempe', 'Pittsburgh', 'Chandler']
for city in cities:
    generate_csv(df, city)

# %%
df_phoenix = pd.read_csv('/content/drive/My Drive/STAT628/data/ImportantSentence/sentence_Phoenix.csv')
df_ttt = df_business[df_business['city']=='Phoenix'].sort_values('review_count', ascending = False)

# %%
bids = df_ttt.business_id.values.tolist()[:30] # see 30 restaruants with most reviews in Phoenix
for bid in bids:
    print(bid)
    sen_list = df_phoenix[df_phoenix['business_id']==bid].important_sentence.tolist()[0].split('|')
    for j in sen_list:
        print(j)
    print()
# Out:
# frCxZS7lPhEnQRJ3UY6m7A
# As much as I loved the salsa bar and the ambiance, I definitely feel like there's some other place out there that has better service and better salsa.
# I asked for a lime (since I'm Mexican and I can't really eat my tacos without lime) and I never got it :( so I stole my boyfriend's lime from the margarita he ordered (without a drink menu by the way cause he was never given one) we finished our food, we payed and left.
# I asked the server what vegetables came with the vegetable chilaquiles but there seemed to be a language barrier; he didn't really understand what I was asking him, only saying yes there are vegetables and when I asked again, that it was a popular choice.
#
# cHdJXLlKNWixBXpDwEGb_A
# I ordered a jade red burrito, they gave me something with slimy pork inside, and I asked for a veggie quesadilla, they gave me a quesadilla with gross fatty chicken and a horrible sauce.
# I feel really bad about giving this place a bad review, especially since they were so nice about giving free samples before I ordered.
# He was so rude, I at this point refused to give my money to such a disrespectful person, so I left and sadly ended up going to jack and a box.
#
# 3C5Z9homtzkWHouH2BHXYQ
# Eventually I got chips and then the folks next to us got food and we hadn't even been asked if we would like to place an order.
# I asked for Coors Light because it was on the drink menu as coming in a bottle, which I prefer, server said they didn't have it, but we have Bud, okay, Bud then.
# We even asked if there was a possibility of getting a quesadilla (since tortillas and cheese are key components of several items) and were told that if it's not listed on the menu, it is not available.
#
# eS29S_06lvsDW04wVrIVxg
# I asked the bartender for a drink and he was very rude and barely even turned around to acknowledge me.
# ) Ok no big deal, i asked for some mayonesa or hollandaise sauce, thats when the service went down.
# My boyfriend got the seafood Chile Relleno and said it was ok - for 21 bucks it should have been way better than ok - I don't eat seafood much so I didn't try it but I've seen him get more excited over a shrimp burrito from Señor Taco.
#
# 7m1Oa1VYV98UUuo_6i0EZg
# Also I asked the dude how long a burger usually takes, just friendly asked, he said oh it takes exactly 3 minutes to cook a burger here so pretty quick sometimes.
# It wasn't the worst I've ever had, but it was definitely lacking.
# The burgers didn't have much flavor, the cheese was ok, the thousand island was runny.
#
# AhPmh0NaRDbEYyhd9egzLA
# The failed start was OK,  with me,  poor guy got in a wreck while talking with me.
# We were asked THREE times by multiple servers if we had a safe way to get home,but instead of them asking it that way, they gave us long dance-around-the-issue schpeels about the community and how they want to keep it safe.
# -While waiting for our bill, at least 4 people asked us if we wanted more chips and salsa.
#
# Wc9UpJhOcdSj7olZkz7SJA
# Then, when I take my first big bite of burger the other woman comes right to my table as I bite down and stands there asking me questions about how my meal was.
# I had to phone back twice and finally got him to speak to me and I asked him about getting the money back I spent on the fries.
# Now the burgers (along with the milkshakes) are hit & miss depending on who is in the kitchen, they continuously mess up your order (as if they actually have more than 3 items on the menu), the folks in the kitchen spend the bulk of their time goofing off rather than putting some effort into the quality/preparation of the food that you're paying them to make, the food is VERY pricey for what you get, & (worst of ALL, in my eyes) the people who take your order are SUPER snobby.
#
# 64dfRmMmUsOdLnkBOtzp4w
# I asked to make reservations and he said well we already have two reservations so I don't think we can get you in, you can just walk up.
# I will start off by saying this is by far the best restaurant the Clarendon has had yet, though that isn't saying much considering their track record.
# I told him " Please bring the Cajetas (the best dessert ever) and the Check" Well while we were still eating our cold tacos.
#
# jsuUmIEefPjV__ads62Z5w
# Dickey's BBQ is just a pit and Dickie's Dog's apparently fed the wrong person a crappy hot dog one too many times and got fire bombs thrown through their front window for their trouble.
# The Eggs Benedit which I love were hard, the sauce dry and the pork, my favorite all dry too as if it had sat for awile keeping warm.
# He disappeared after giving me the beer and ten minutes later came back and asked if we knew what we wanted or had questions.
#
# ElWzx5_fU8S2G45OnM-HpA
# Not the worst food, but the worst experience.
# Not the worst food, but the worst experience.
# Didn't ask for a discount or manager or anything, just super bummed it was such poor quality, bland and just over-all bad food.
#
# fbQaKW0Lte0JQ_opbnjdKg
# I asked for a sample of the chicken because I've never been and was having a hard time ordering, the guy looked at me like I was stupid for asking.
# Well probably be back to try them one more time as I really want these guys to succeed because I live right down the street and I love their concept, but if I get another room temperature bowl of soup it'll definitely be a MAJOR issue.
# I guess I was really expecting more, considering all the positive reviews I read and this is why I feel terrible for saying the food at  Gadzooks was bland and poorly executed.
#
# P8IsTiHq5Hesa6UPL604ww
# I want to give this place five stars and brag right and left that this is the place to be.
# I got the response "it's coming up, it's next" and "just a few minutes more" finally I ask one last time and my order was sitting on the counter bagged up with the receipt taped with my name clearly on the tab.
# There were no straws so I asked nicely for one and was given a look of hate and finally got my straw.
#
# zJGtD3y-pAIGNId4codEEg
# My husband said we aren't eating if you can't eat so we told them never mind give us the check and we will try another time.
# It normally takes things like bad food, bad service, and an overall bad experience.
# From the time it took us to ask for the dessert menu, get it, and the waitress finally come back to ask what we wanted it had been 30 MIN.
#
# HGvNE87fvK5PwKMZBDkTbA
# Your wife's service was not bad, I never said her service was bad, just not attentive like I mentioned above.
# I sat there asking her what she could do and all she could say was that I could order two more entrees or settle the bill and leave.
# Another Phoenix restaurant getting away w/ poor customer service, sub-par food, high prices and A HORRIBLE HOST.
#
# _WtxQbDK7B-ExGdeG-2j6Q
# They came back out 10 minutes later, the same plates, and the bartender asked us to cut in and make sure they were cooked.
# If people said, its a decent bar with good food, i would say: "heck yes, 4 stars, just needs some better service.
# "He blew me off" and finally we out there and cleaned off my table and didn't say anything when he walked in till I got in front of him and asked him are we good to seat down it's been fifteen mins he said yes with an attitude.
#
# 89uU51kOiQXbJHVA3C6XMQ
# When we got our order, our kids enjoyed their burritos, my husband was OK with his, enjoyed the tortilla very much, but said that nothing special, and me, when I started eating it, a white goo came flowing out.
# It was all fine for what it is (I guess) but nothing that I would particularly go out of my way for, with the exception of the homemade flour tortillas, which were awesome.
# She was starting to tell the cooks to make my order but at this point I asked for my receipt back because I wanted my money back.
#
# 2g4ZTD3ePNSbDAvh6qAOKQ
# I may give this place another try but definitely not the Mexican shrimp cocktail.
# Are people just giving this place good reviews bc they want to pretend like they're super cool and are totally down with hole in the wall places in the hood.
# ) ok so like the top half started out good but then I got grossed out with all the meat and then took off the fried chicken an chicken fried steak.
#
# JfHXzulF6yIKgA22YYPedw
# After trying to eat what was very poorly made food (we couldn't eat it because it was horrible) we went to pay the bill and noticed extra charges.
# The beans tasted and horrible and I asked the server what was in the beans.
# We proceeded to wait for 15 minutes to have a server even approach us for drinks, with many tables being seated and served well after our arrival and before we even got a "hello".
#
# xZhNZb01n9b4e2X7bZdoVQ
# I will tell you that this place is getting one star solely on the absolutely terrible food I had and the awful service.
# We walked in and we were seated quickly, the sever took our drink orders and before we even had time to look at the menu he asked if we were ready to order, obviously not we just sat down.
# The accompanying salsa(which definitely spent the night in the fridge)was ok a bit on the salty side.
#
# jIzygnVmajEXYmfsBNY_Gw
# Maybe I got the bad batch that fateful Friday afternoon.
# The kid then comes out and asks what the problem was, I just said she couldn't hear me so I stopped repeating myself.
# And if you want fancy tacos, there are much better places to get fancy tacos.
#
# 7Q2cYSl5NBYytJzgjX0oKw
# I guess the waitress felt like she needed Justin "The VIP Host" and he comes over and doesn't say hello or nothing just goes into NO YOU CANT MOVE TABLES and I told you over the phone that the tables seat 6.
# Eventually a female bartender walks around and says nothing but "what can I get you guys" serves us our beer, and takes my cash.
# He looked upset with this face ,almost like the other man waitress, ( ANNOYED LOOK) young kid, so rude, came back twice to interrupt us in less than 5 minutes,  I think just to purposely to be rude.
#
# -bMZCfTK7fxFaURynKpBMA
# Horrible service , waiting 49 minutes for a table, waitress took another 10 minuets to come and take our drink order , waitress left with our drink order (Margarita and beer) came back without drinks , took our food order , waited another 15 minutes still no drinks , but food arrived , ordered a shrimp cocktail and 2 shrimp tostadas and 3 tacos , still no drinks.
# I had to ask for all the dirty dishes to be taken away as nobody came to take them.
# He stuck his thumb in one of them and said "it's cold" then says "do you guys still want it.
#
# T-KniGykrZ46ZC9plOTspw
# If there's one thing I can conclude from eating at the Mexican places that are most highly rated on Yelp, it's that white people have very bad taste for Mexican food.
# Then the one who ordered last, who is now sitting across from me gets his order, right then I asked the gentleman, same one who asked/ordered me to spread the word,  "what about my order.
# Not the worst burrito I have ever had, but far from good, even.
#
# Ns20WGWn6s6niKAGIQB4UQ
# He asks for what kind of whiskey is used in the Old Fashion and again the guy points at the menu and says, "It says right here.
# And if you ask why you are paying an additional $5 for $20 tickets AT THE VENUE there's a guy server who clearly thinks he's still a bouncer at whatever the last shit hole he worked at is, who is more than happy to get in your face SUPER aggressively about it and tell you you can fuck off and try to buy your tickets elsewhere if you don't like it.
# Never thought I would ever have those words come out of my mouth even in Arizona.
#
# DaVTuhzi6EgWStb2eAjNjA
# It took some more time for the manager to correct this mistake- if we hadn't said anything we would've been charged an additional $20, and this time, our waiter gave us an apology for overcharging us.
# I would love to open up a restaurant right near him because my son (a chef) and I would put this rude oaf out of business.
# I am OK with paying higher prices for good food, but I want the rest of the experience to match the price.
#
# qnn9E-e9orYf_wK37yLTYw
# The fajitas were asked to have half/half steak and chicken but I asked three times to make sure the chicken is not over cooked as chicken breast will dry out immediately when it is not cooked properly.
# Like I always say you can always tell the quality of a Mexican food restaurant by the salsa, beans, and rice.
# I ordered my food and when the server asked which beans I asked which ones have bacon in them, told her I don't eat meat and then took the black beans (no bacon).
#
# of4V8nfW7GwJ03tLDdrOlA
# The burrito though, I had high hopes, the chicken looked like the stuff you can get at the store, the deli fresh grilled chicken breast, it was perfectly sliced with grill marks, had no flavor at all, the peppers, onions and garlic was bland, no flavor, the goat cheese didn't have that bite it normally has, the cream reduction was like a thin alfredo sauce but bland.
# The couple next to me paid their check and asked "Has anyone even gotten you a drink yet.
# Three people order after me within 15 minutes, each ordering items on the menu of similar preparation (one even got the same dish).
#
# YauBkH-HEx148jC0pv4Hcg
# We overheard the waitress ask the patrons when they were asking for their check, "Did you ever get the beer you ordered.
# When she finally showed up she was ready to take our order but didn't ask about the appetizers, so we told her they were presented cold.
# Again I had to ask the server to please ask the bartender, or whomever was supposed to be working behind the bar, to please see if someone was available to serve us.
#
# pDewiJY6KCcZgLxxgxg13Q
# The chicken taco and enchilada were OK.
# It was ok, I ate some of it and took the rest home to palm it off on someone else in the house.
# Bad customer service, horrible smelling bathrooms, and no care for their customers will eventually hurt them.
#
# jzM4dTlstNmGDPRT9SC6Hw
# When the appetizer arrived i asked the buzzer for silverware, he said ok and left.
# We didn't have place settings and when we asked for some she brought us three (for seven of us) so we had to ask a second time.
# Worst service I have ever had and cold food that was simply not very good.

# %%
bids = ['frCxZS7lPhEnQRJ3UY6m7A', '3C5Z9homtzkWHouH2BHXYQ', 'cHdJXLlKNWixBXpDwEGb_A', 
        'of4V8nfW7GwJ03tLDdrOlA', 'Wc9UpJhOcdSj7olZkz7SJA', '_WtxQbDK7B-ExGdeG-2j6Q']
for bid in bids:
    print(df_business[df_business['business_id']==bid].name.tolist()[0])
    print(df_phoenix[df_phoenix['business_id']==bid].indexes.tolist()[0])
    sen_list = df_phoenix[df_phoenix['business_id']==bid].important_sentence.tolist()[0].split('|')
    for j in sen_list:
        print(j)
    print()
# Out:
# La Santisima
# [261607, 282304, 282236]
# As much as I loved the salsa bar and the ambiance, I definitely feel like there's some other place out there that has better service and better salsa.
# I asked for a lime (since I'm Mexican and I can't really eat my tacos without lime) and I never got it :( so I stole my boyfriend's lime from the margarita he ordered (without a drink menu by the way cause he was never given one) we finished our food, we payed and left.
# I asked the server what vegetables came with the vegetable chilaquiles but there seemed to be a language barrier; he didn't really understand what I was asking him, only saying yes there are vegetables and when I asked again, that it was a popular choice.
#
# Taco Guild
# [214960, 220842, 227485]
# Eventually I got chips and then the folks next to us got food and we hadn't even been asked if we would like to place an order.
# I asked for Coors Light because it was on the drink menu as coming in a bottle, which I prefer, server said they didn't have it, but we have Bud, okay, Bud then.
# We even asked if there was a possibility of getting a quesadilla (since tortillas and cheese are key components of several items) and were told that if it's not listed on the menu, it is not available.
#
# Chino Bandido
# [20995, 2633, 20521]
# I ordered a jade red burrito, they gave me something with slimy pork inside, and I asked for a veggie quesadilla, they gave me a quesadilla with gross fatty chicken and a horrible sauce.
# I feel really bad about giving this place a bad review, especially since they were so nice about giving free samples before I ordered.
# He was so rude, I at this point refused to give my money to such a disrespectful person, so I left and sadly ended up going to jack and a box.
#
# Barrio Cafe
# [249741, 262422, 288654]
# The burrito though, I had high hopes, the chicken looked like the stuff you can get at the store, the deli fresh grilled chicken breast, it was perfectly sliced with grill marks, had no flavor at all, the peppers, onions and garlic was bland, no flavor, the goat cheese didn't have that bite it normally has, the cream reduction was like a thin alfredo sauce but bland.
# The couple next to me paid their check and asked "Has anyone even gotten you a drink yet.
# Three people order after me within 15 minutes, each ordering items on the menu of similar preparation (one even got the same dish).
#
# The Stand
# [287512, 279535, 260582]
# Then, when I take my first big bite of burger the other woman comes right to my table as I bite down and stands there asking me questions about how my meal was.
# I had to phone back twice and finally got him to speak to me and I asked him about getting the money back I spent on the fries.
# Now the burgers (along with the milkshakes) are hit & miss depending on who is in the kitchen, they continuously mess up your order (as if they actually have more than 3 items on the menu), the folks in the kitchen spend the bulk of their time goofing off rather than putting some effort into the quality/preparation of the food that you're paying them to make, the food is VERY pricey for what you get, & (worst of ALL, in my eyes) the people who take your order are SUPER snobby.
#
# Rokerij
# [316111, 324146, 295177]
# They came back out 10 minutes later, the same plates, and the bartender asked us to cut in and make sure they were cooked.
# If people said, its a decent bar with good food, i would say: "heck yes, 4 stars, just needs some better service.
# "He blew me off" and finally we out there and cleaned off my table and didn't say anything when he walked in till I got in front of him and asked him are we good to seat down it's been fifteen mins he said yes with an attitude.
